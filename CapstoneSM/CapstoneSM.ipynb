# %% [markdown]
# # Capstone Project
# # Data Science Academy 2022
# ### Sarita Mishra

# %%
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
import csv
import plotly.express as px

# %% [markdown]
# # Fuzzy Wuzzy Sample Code
# Str_A = 'FuzzyWuzzy is a lifesaver!'
# Str_B = 'fuzzy wuzzy is a LIFE SAVER.'
# ratio = fuzz.ratio(Str_A.lower(), Str_B.lower())
# print('Similarity score: {}'.format(ratio))

# %%
#help(pd.DataFrame)

# %%
# read capstone data to data frame
def match_states(statename, list_names, list_abbrs, min_score=0):
    max_score = -1
    max_name = ''
    for x in list_names:
        #print(x)
        #score = fuzz.partial_ratio(statename.lower(), x.lower()) 
        score = fuzz.token_sort_ratio(statename.lower(), x.lower()) 
        if (score > min_score) & (score > max_score):
            max_name = x   
            #print(max_name)
            max_score = score
            
        if(max_score < 75):
            # look in the abbr list
            for a in list_abbrs:
                score = fuzz.ratio(statename.lower(), a.lower()) 
                if (score > min_score) & (score > max_score):
                    if(statename.lower() == ''):
                        max_name = 'Other'
                        max_score = '0'
                    else:
                        max_name = a
                        max_score = score
    
    
    return (max_name, max_score)

# %%
#read the csv file and return dataframe
def read_file_to_data_frame(filePath, delimiter):    
    df = pd.read_csv(filePath,sep=delimiter)
   # print(df.head)
    return df

# %%
#Read and Write to CSV file
def read_write_csv_file(readfilePath, writefilepath):
    # header row
    header = []
    rows = []
    with open(readfilePath) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                print(f'Column names are {", ".join(row)}')
                header.append(row)
                line_count += 1
            else:                                
                strloc = row[-2]
                #print(f'\t{strloc}')                
                nrow = row
                line_count += 1
                if(strloc.find(",") >= 0):
                    #print(strloc)
                    strr = strloc.replace(',', ' ')
                    nrow[-2] = strr
                    #print(f'\t{nrow[-2]}')
                    rows.append(nrow)
                else:
                    rows.append(row)
                    #print(nrow)
    
    print(f'Processed {line_count} lines.')
    
    with open(writefilepath, mode='w') as csvw_file:        
        #writer = csv.DictWriter(csv_file, fieldnames=header)
        writer = csv.writer(csvw_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer.writerow(header)
        print("rows count" + str(len(rows)))
        for wrow in rows:
            writer.writerow(wrow)

# %%
#Create a Dictionary of States
def get_state_dictionary(df_sts):
    lst_st = []
    dict_st = df_sts.to_dict(orient='records')
    dict_ct = {}
    for row in dict_st:
       # print(row)
        #print(row['name'])
        dict_ct[row['name']] = row['abbr']
        
    for a in dict_st:
       # print(a)
        dict_ct[a['abbr']] = a['abbr']
    
    # Add valid 'Other'
    
    dict_ct['Other'] = 'Other'
    
    return dict_ct

# %%
def get_clean_parsed_data(path_cs, path_st, delimiter):
    
    try:     

        df_cs = read_file_to_data_frame(path_cs, delimiter)    
        df_st = read_file_to_data_frame(path_st, '\t')
       # print(df_st.head)
        dict_sts = get_state_dictionary(df_st)
       # print(dict_sts)
        #print(dict_sts['NJ'])
        lst_cs_states = list(df_cs.state)
        
        #list of State Names
        lst_st_names = list(df_st.name.unique())
        #print(lst_st_names)
        #list of state abbr
        lst_st_abbr = list(df_st.abbr.unique())
        #print(lst_st_abbr)       
        
       # print(dict_sts)
        # Add keys and values in a dictionary
        lst_sts = []
        mismatch = []
        
        for x in lst_cs_states:
            #print(x)
            match = match_states(x, lst_st_names, lst_st_abbr, 0)
            #print(match)
            if match[1] > 0:
                #print(str(dict_sts[match[0]]))
                name1 = (str(dict_sts[match[0]]))
                #name = ('(' + str(x), name1 + ')')
                name = ( str(x), name1)
                lst_sts.append(name)
        state_dict = dict(lst_sts)
              
        #print(state_dict)
        
        #print(mismatch)
       
        df_cs.state  = df_cs.state.replace(state_dict)
        df_cs.insert(0,'Candidate_ID', range(1, 1 + len(df_cs)))
        #print(df_cs)
        return df_cs
        
    except:
        print('Error')

# %%
def draw_plot_scatter(df):
    fig1 = px.scatter(df, x="sum_score", y="rt_total", size="Candidate_ID", color="gender")
    fig2 = px.histogram(df, x="sum_score", color="state", facet_col='gender')
    
    fig1.show()
    fig2.show()
    return

# %%
def main():
    path_cs = 'C://Users/snmishra/OneDrive - Educational Testing Service/DataScienceAcademy/DataScienceAcademyHomework/DataScienceAcademy/CapstoneSM/Data/data_capstone_dsa2021_2022.csv'
    path_st = 'C://Users/snmishra/OneDrive - Educational Testing Service/DataScienceAcademy/DataScienceAcademyHomework/DataScienceAcademy/CapstoneSM/Data/states.csv'
    path_clean = 'C://Users/snmishra/OneDrive - Educational Testing Service/DataScienceAcademy/DataScienceAcademyHomework/DataScienceAcademy/CapstoneSM/Data/data_capstone4.csv'
    delimiter = ','
    #One time clean
    #read_write_csv_file(path_cs,path_clean) One time clean
    # cleaned dataframe 
    df_capstone = get_clean_parsed_data(path_clean, path_st, delimiter)
    # generate plot graphs
    draw_plot_scatter(df_capstone)
    return

main()
# Out:
# <div>                            <div id="4d6ca227-97aa-4671-ad3f-9be8599f75b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d6ca227-97aa-4671-ad3f-9be8599f75b0")) {                    Plotly.newPlot(                        "4d6ca227-97aa-4671-ad3f-9be8599f75b0",                        [{"hovertemplate":"gender=Male<br>sum_score=%{x}<br>rt_total=%{y}<br>Candidate_ID=%{marker.size}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa","size":[1,2,5,6,8,12,17,21,31,33,35,38,39,40,41,43,44,45,46,49,50,53,56,58,60,61,62,64,67,68,69,70,72,74,75,78,79,80,81,84,86,88,89,90,93,94,96,97,100,103,106,107,108,110,111,115,117,118,119,120,123,124,125,128,129,130,131,133,134,136,138,139,140,142,143,145,146,147,153,155,157,158,159,160,163,164,169,170,172,174,177,178,180,181,182,183,185,188,192,194,199,200,201,205,207,208,210,211,214,215,216,222,233,235,238,239,248,250,252,253,254,255,256,257,259,260,261,262,263,266,267,268,269,270,271,273,274,276,277,278,279,281,282,284,285,288,290,294,295,298,299,302,305,307,308,311,312,315,316,321,323,325,326,327,331,333,336,339,341,342,343,344,345,348,350,351,353,355,356,357,358,360,364,365,369,370,372,373,375,377,378,379,380,382,384,385,387,390,393,394,397,398,402,403,406,407,408,410,411,413,414,415,418,420,422,423,427,433,434,435,436,437,438,440,441,442,443,445,448,449,450,451,452,453,454,455,456,459,460,465,467,470,474,475,479,481,484,485,487,489,490,494,495,499,500,505,506,508,509,510,515,516,518,521,525,526,527,531,532,533,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,552,555,559,560,561,563,564,565,566,567,569,570,571,572,574,576,578,580,581,584,586,588,589,592,594,595,597,598,601,602,604,607,610,615,617,618,619,621,622,626,631,633,634,636,638,639,641,647,648,652,655,657,658,660,661,664,666,676,684,685,687,691,692,694,700,704,707,709,710,711,716,718,720,724,725,726,731,733,735,737,739,740,741,742,744,746,747,748,750,755,756,759,760,761,762,763,768,774,776,780,781,783,786,789,794,796,798,800,805,807,815,816,817,821,823,827,828,829,830,831,837,838,839,843,844,845,849,853,860,861,862,869,871,872,873,876,878,879,883,890,891,894,896,897,903,906,908,909,911,913,914,916,917,919,920,924,925,934,939,942,946,947,953,954,955,956,957,958,959,960,961,964,965,967,968,969,971,973,975,978,979,983,984,986,992,993,994,995,999,1001,1007,1008,1010,1015,1016,1017,1018,1019,1023,1025,1026,1027,1028,1030,1031,1032,1034,1038,1039,1040,1041,1042,1043,1045,1046,1049,1050,1051,1052,1057,1059,1061,1062,1063,1064,1065,1067,1068,1070,1073,1074,1075,1076,1077,1079,1083,1084,1086,1087,1089,1092,1093,1094,1095,1096,1098,1100,1102,1103,1104,1106,1109,1110,1112,1116,1117,1120,1122,1123,1124,1128,1129,1130,1131,1133,1134,1135,1136,1137,1142,1145,1146,1147,1149,1150,1151,1154,1155,1156,1159,1160,1161,1162,1164,1165,1168],"sizemode":"area","sizeref":2.9225,"symbol":"circle"},"mode":"markers","name":"Male","showlegend":true,"x":[19,19,17,17,19,19,20,18,19,15,19,17,16,15,20,18,17,20,19,20,20,20,20,20,19,19,20,18,14,19,19,18,17,19,20,19,19,17,19,20,19,18,18,19,20,17,19,14,19,18,20,18,20,13,18,18,19,17,20,18,19,13,20,19,11,17,19,11,19,19,20,15,20,18,18,17,16,18,16,8,18,19,18,19,19,19,15,20,20,19,17,20,20,17,20,17,18,19,20,18,20,14,19,19,17,19,18,18,10,19,11,19,19,3,12,19,13,19,19,16,20,20,19,18,20,20,18,18,15,15,18,17,10,12,18,19,20,20,15,15,19,12,20,19,7,15,19,17,15,19,19,19,18,19,17,18,20,19,18,15,18,19,16,18,18,16,20,20,17,19,20,17,18,15,14,18,9,20,18,17,17,13,18,12,17,19,15,18,18,15,18,19,20,12,15,16,19,19,8,18,15,17,19,17,18,18,19,16,18,19,20,19,15,17,18,18,19,19,15,15,19,18,19,17,20,20,18,11,17,17,16,15,19,14,17,18,16,15,20,18,18,20,20,18,8,19,20,18,18,18,17,19,16,18,19,16,19,19,13,18,19,19,20,19,19,19,17,18,14,19,16,19,17,19,18,15,16,15,18,19,18,20,20,16,20,17,15,18,17,20 ...
# <div>                            <div id="fdf6fe2e-55ff-4fde-b903-fb942d3a323f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdf6fe2e-55ff-4fde-b903-fb942d3a323f")) {                    Plotly.newPlot(                        "fdf6fe2e-55ff-4fde-b903-fb942d3a323f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=WI<br>gender=Male<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"WI","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"WI","offsetgroup":"WI","orientation":"v","showlegend":true,"x":[19,19,19,20,18,18,19,17,16,18,16],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=WI<br>gender=Female<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"WI","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"WI","offsetgroup":"WI","orientation":"v","showlegend":false,"x":[19,16,17,19,18,17,18,20,19,18,20,17,19],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=VA<br>gender=Male<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"VA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"VA","offsetgroup":"VA","orientation":"v","showlegend":true,"x":[19,19,16,20,20,20,19],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=VA<br>gender=Female<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"VA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"VA","offsetgroup":"VA","orientation":"v","showlegend":false,"x":[19,19,18,19,18,20,20,17,17,13,17,8,18],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=LA<br>gender=Male<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"LA","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LA","offsetgroup":"LA","orientation":"v","showlegend":true,"x":[17,19,18,12,15,19,19,10],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=LA<br>gender=Female<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"LA","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LA","offsetgroup":"LA","orientation":"v","showlegend":false,"x":[17,19,16,20,13,18,15,15,12,12,17,18,19,18,16,16],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=MD<br>gender=Male<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"MD","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"MD","offsetgroup":"MD","orientation":"v","showlegend":true,"x":[18,17,17,20,17,19,19,19,18,10,20,17,20,20],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=MD<br>gender=Female<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"MD","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"MD","offsetgroup":"MD","orientation":"v","showlegend":false,"x":[15,18,15,16,19,14,18,19,17,19,14,17,20,15],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=CA<br>gender=Male<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"CA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"CA","offsetgroup":"CA","orientation":"v","showlegend":true,"x":[17,19,17,20,18,20,19,18,18,19,3,20,18,15,19,18,15,20,15,14,19,17,19,19,17,20,14,19,18,17,20,16,20,20,16,16,18,17,19,19,20,13,20,16,19,15,17,17,19,11,20,17],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=CA<br>gender=Female<br>sum_score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"CA","mar ...

# %%
path_cs = 'C://Users/snmishra/OneDrive - Educational Testing Service/DataScienceAcademy/DataScienceAcademyHomework/DataScienceAcademy/CapstoneSM/Data/data_capstone_dsa2021_2022.csv'
path_st = 'C://Users/snmishra/OneDrive - Educational Testing Service/DataScienceAcademy/DataScienceAcademyHomework/DataScienceAcademy/CapstoneSM/Data/states.csv'
delimiter = ','

df_cs = read_file_to_data_frame(path_cs, delimiter)
#print(df_cs.head)
df_st = read_file_to_data_frame(path_st, '\t')
#print(df_st.head)
dict_sts = get_state_dictionary(df_st)
print(dict_sts)
print(dict_sts['NJ'])
df_cs_states = list(df_cs.state.unique())
#print(df_cs_states)

#list of State Names
lst_st_names = list(df_st.name.unique())
#print(lst_st_names)
#list of state abbr
lst_st_abbr = list(df_st.abbr.unique())
#print(lst_st_abbr)

# Add keys and values in a dictionary
lst_sts = []
for x in df_cs_states:
    #print(x)
    match = match_states(x, lst_st_names, lst_st_abbr, 0)
    #print(match)
    if match[1] >= 75:
        name = ('(' + str(x), str(match[0]) + ')')
        lst_sts.append(name)
state_dict = dict(lst_sts)
state_dict
# Out:
# {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut ': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY', 'AL': 'AL', 'AK': 'AK', 'AZ': 'AZ', 'AR': 'AR', 'CA': 'CA', 'CO': 'CO', 'CT': 'CT', 'DE': 'DE', 'FL': 'FL', 'GA': 'GA', 'HI': 'HI', 'ID': 'ID', 'IL': 'IL', 'IN': 'IN', 'IA': 'IA', 'KS': 'KS', 'KY': 'KY', 'LA': 'LA', 'ME': 'ME', 'MD': 'MD', 'MA': 'MA', 'MI': 'MI', 'MN': 'MN', 'MS': 'MS', 'MO': 'MO', 'MT': 'MT', 'NE': 'NE', 'NV': 'NV', 'NH': 'NH', 'NJ': 'NJ', 'NM': 'NM', 'NY': 'NY', 'NC': 'NC', 'ND': 'ND', 'OH': 'OH', 'OK': 'OK', 'OR': 'OR', 'PA': 'PA', 'RI': 'RI', 'SC': 'SC', 'SD': 'SD', 'TN': 'TN', 'TX': 'TX', 'UT': 'UT', 'VT': 'VT', 'VA': 'VA', 'WA': 'WA', 'WV': 'WV', 'WI': 'WI', 'WY': 'WY'}
# NJ
# {'(wisconsin': 'Wisconsin)',
#  '(Virginia': 'Virginia)',
#  '(Maryland': 'Maryland)',
#  '(California': 'California)',
#  '(Mississippi': 'Mississippi)',
#  '(Utah': 'Utah)',
#  '(North Carolina': 'North Carolina)',
#  '(Ohio': 'Ohio)',
#  '(Florida': 'Florida)',
#  '(GA': 'GA)',
#  '(West Virginia': 'West Virginia)',
#  '(Virginia, USA': 'Virginia)',
#  '(Michigan': 'Michigan)',
#  '(MN': 'MN)',
#  '(Illinois': 'Illinois)',
#  '(Indiana': 'Indiana)',
#  '(PA': 'PA)',
#  '(Arizona': 'Arizona)',
#  '(Pennsylvania': 'Pennsylvania)',
#  '(Missouri': 'Missouri)',
#  '(florida': 'Florida)',
#  '(New York': 'New York)',
#  '(colorado': 'Colorado)',
#  '(tennessee': 'Tennessee)',
#  '(Texas': 'Texas)',
#  '(maryland': 'Maryland)',
#  '(ohio': 'Ohio)',
#  '(Oregon': 'Oregon)',
#  '(Alabama': 'Alabama)',
#  '(NH': 'NH)',
#  '(Kentucky': 'Kentucky)',
#  '(tennesee': 'Tennessee)',
#  '(NJ': 'NJ)',
#  '(Minnesota': 'Minnesota)',
#  '(AL': 'AL)',
#  '(Georgia': 'Georgia)',
#  '(Tennessee': 'Tennessee)',
#  '(Lousiana': 'Louisiana)',
#  '(New Jersey': 'New Jersey)',
#  '(Massachusetts': 'Massachusetts)',
#  '(NC': 'NC)',
#  '(Washington': 'Washington)',
#  '(Washington State': 'Washington)',
#  '(NY': 'NY)',
#  '(Oklahoma': 'Oklahoma)',
#  '(Wisconsin': 'Wisconsin)',
#  '(MO': 'MO)',
#  '(CA': 'CA)',
#  '(utah': 'Utah)',
#  '(Hawaii': 'Hawaii)',
#  '(texas': 'Texas)',
#  '(alabama': 'Alabama)',
#  '(Illinois, USA': 'Illinois)',
#  '(South Carolina': 'South Carolina)',
#  '(Rhode Island': 'Rhode Island)',
#  '(north carolina': 'North Carolina)',
#  '(washington': 'Washington)',
#  '(Kansas': 'Kansas)',
#  '(boston massachusetts': 'Massachusetts)',
#  '(WI': 'WI)',
#  '(TN': 'TN)',
#  '(Nebraska': 'Nebraska)',
#  '(NEW YORK': 'New York)',
#  '(indiana': 'Indiana)',
#  '(Maryland, USA': 'Maryland)',
#  '(sc': 'SC)',
#  '(Delaware': 'Delaware)',
#  '(New Hampshire': 'New Hampshire)',
#  '(SOUTH CAROLINA': 'South Carolina)',
#  '(TX': 'TX)',
#  '(Colorado': 'Colorado)',
#  '(NORTH CAROLINA': 'North Carolina)',
#  '(Louisiana': 'Louisiana)',
#  '(michigan': 'Michigan)',
#  '(Pennsylvania, USA': 'Pennsylvania)',
#  '(Massachusettes': 'Massachusetts)',
#  '(California, USA': 'California)',
#  '(OKlahoma': 'Oklahoma)',
#  '(WV': 'WV)',
#  '(Idaho': 'Idaho)',
#  '(India': 'Indiana)',
#  '(pennsylvania': 'Pennsylvania)',
#  '(SC': 'SC)',
#  '(Arkansas': 'Arkansas)',
#  '(New Mexico': 'New Mexico)',
#  '(ny': 'NY)',
#  '(new york': 'New York)',
#  '(Pennsyvania': 'Pennsylvania)',
#  '(illinois': 'Illinois)',
#  '(Missouri, USA': 'Missouri)',
#  '(Georgia, US': 'Georgia)',
#  '(missouri': 'Missouri)',
#  '(Caflifornia': 'California)',
#  '(Tennessee, USA': 'Tennessee)',
#  '(Nevada': 'Nevada)',
#  '(AZ': 'AZ)',
#  '(WA': 'WA)',
#  '(FL': 'FL)',
#  '(Iowa': 'Iowa)',
#  '(nc': 'NC)',
#  '(KY': 'KY)',
#  '(Montana': 'Montana)',
#  '(Connecticut': 'Connecticut )',
#  '(california': 'California)',
#  '(hawaii': 'Hawaii)',
#  '(Michigan, USA': 'Michigan)',
#  '(md': 'MD)',
#  '(SD': 'SD)',
#  '(minnesota': 'Minnesota)',
#  '(Michigan (US)': 'Michigan)',
#  '(maine': 'Maine)',
#  '(Arkansas, USA': 'Arkansas)',
#  '(nebraska': 'Nebraska)',
#  '(tx': 'TX)',
#  '(Alaska': 'Alaska)',
#  '(Maine': 'Maine)',
#  '(New York, USA': 'New York)',
#  '(connecticut': 'Connecticut )',
#  '(MA': 'MA)',
#  '(CO': 'CO)',
#  '(tennessee, usa': 'Tennessee)',
#  '(WISCONSIN': 'Wisconsin)',
#  '(North Carolina, USA': 'North Carolina)',
#  '(New York Ciry': 'New York)',
#  '(New York City': 'New York)',
#  '(new jersey': 'New Jersey)',
#  '(OH': 'OH)',
#  '(Worthington': 'Washington)',
#  '(RI': 'RI)',
#  '(New York USA': 'New York)',
#  '(MICHIGAN': 'Michigan)',
#  '(idaho': 'Idaho)',
#  '(maryland, usa': 'Maryland)',
#  '(Michigan, US': 'Michigan)',
#  '(FLORIDA': 'Florida)',
#  '(LA': 'LA)',
#  '(Michigan USA': 'Michigan)',
#  '(New  Jersey USA': 'New Jersey)',
#  '(New York, US': 'New York)',
#  '(Louisiana, USA': 'Louisiana)',
#  '(CT': 'CT)',
#  '(ga': 'GA)',
#  '(ILLINOIS': 'Illinois)',
#  '(arizona': 'Arizona)',
#  '(michigan, usa': 'Michigan)',
#  '(californi': 'California)',
#  '(kansas': 'Kansas)',
#  '(W.V': 'WV)',
#  '(Pennsylvania, US': 'Pennsylvania)',
#  '(louisiana': 'Louisiana)',
#  '(rhode island': 'Rhode Island)',
#  '(illinois, usa': 'Illinois)',
#  '(Vermont USA': 'Vermont)',
#  '(Ma': 'MA)',
#  '(MI': 'MI)',
#  '(Washington DC': 'Washington)',
#  '(fl': 'FL)',
#  '(IN': 'IN)',
#  '(california usa': 'California)',
#  '(kentucky': 'Kentucky)',
#  '(IL': 'IL)',
#  '(mo': 'MO)',
#  '(South Carolina USA': 'South Carolina)',
#  '(South Dakota': 'South Dakota)',
#  '(Minnesota USA': 'Minnesota)',
#  '(connecticut usa': 'Connecticut )',
#  '(VA': 'VA)',
#  '(INDIANA': 'Indiana)',
#  '(virginia': 'Virginia)',
#  '(nj': 'NJ)',
#  '(oklahoma': 'Oklahoma)',
#  '(Maryland USA': 'Maryland)',
#  '(CALIFORNIA': 'California)',
#  '(Vermont': 'Vermont)',
#  '(North Carolina USA': 'North Carolina)',
#  '(iowa': 'Iowa)',
#  '(georgia': 'Georgia)',
#  '(New  York': 'New York)',
#  '(oh': 'OH)',
#  '(massachusetts': 'Massachusetts)',
#  '(HI': 'HI)',
#  '(Maryland/USA': 'Maryland)',
#  '(va': 'VA)',
#  '(TEXAS': 'Texas)',
#  '(USA, New Jersey': 'New Jersey)'}
